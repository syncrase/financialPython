# %% [markdown]
# https://finnhub.io/dashboard

# %%
# Necessary Libraries.
import requests
import json
import pandas as pd
import numpy as np

# Specify the stock that you want to analyze.
stock = 'TSLA'
API_KEY = 'c899flaad3ie4jitucs0'
# Request for data from Finhub.io (30 calls per second limit: https://finnhub.io/docs/api/rate-limit).
r = requests.get('https://finnhub.io/api/v1/stock/insider-transactions?symbol=' + stock + '&token=' + API_KEY)

# Load the JSON file as a string.
test = json.loads(r.text)
test
# Out:
# {'data': [{'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 5000,
#    'change': -10100,
#    'filingDate': '2022-02-03',
#    'transactionDate': '2022-02-01',
#    'transactionCode': 'S',
#    'transactionPrice': 934.124},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 15100,
#    'change': -300,
#    'filingDate': '2022-02-03',
#    'transactionDate': '2022-02-01',
#    'transactionCode': 'S',
#    'transactionPrice': 932.853},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 15400,
#    'change': -200,
#    'filingDate': '2022-02-03',
#    'transactionDate': '2022-02-01',
#    'transactionCode': 'S',
#    'transactionPrice': 931.655},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 15600,
#    'change': -100,
#    'filingDate': '2022-02-03',
#    'transactionDate': '2022-02-01',
#    'transactionCode': 'S',
#    'transactionPrice': 929.89},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 15700,
#    'change': -600,
#    'filingDate': '2022-02-03',
#    'transactionDate': '2022-02-01',
#    'transactionCode': 'S',
#    'transactionPrice': 926.482},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 16300,
#    'change': -800,
#    'filingDate': '2022-02-03',
#    'transactionDate': '2022-02-01',
#    'transactionCode': 'S',
#    'transactionPrice': 925.046},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 17100,
#    'change': -400,
#    'filingDate': '2022-02-03',
#    'transactionDate': '2022-02-01',
#    'transactionCode': 'S',
#    'transactionPrice': 923.823},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 17500,
#    'change': -600,
#    'filingDate': '2022-02-03',
#    'transactionDate': '2022-02-01',
#    'transactionCode': 'S',
#    'transactionPrice': 922.302},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 18100,
#    'change': -300,
#    'filingDate': '2022-02-03',
#    'transactionDate': '2022-02-01',
#    'transactionCode': 'S',
#    'transactionPrice': 920.853},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 18400,
#    'change': -400,
#    'filingDate': '2022-02-03',
#    'transactionDate': '2022-02-01',
#    'transactionCode': 'S',
#    'transactionPrice': 919.733},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 18800,
#    'change': -700,
#    'filingDate': '2022-02-03',
#    'transactionDate': '2022-02-01',
#    'transactionCode': 'S',
#    'transactionPrice': 918.914},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 19500,
#    'change': -400,
#    'filingDate': '2022-02-03',
#    'transactionDate': '2022-02-01',
#    'transactionCode': 'S',
#    'transactionPrice': 917.345},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 19900,
#    'change': -1020,
#    'filingDate': '2022-02-03',
#    'transactionDate': '2022-02-01',
#    'transactionCode': 'S',
#    'transactionPrice': 916.549},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 20920,
#    'change': -1024,
#    'filingDate': '2022-02-03',
#    'transactionDate': '2022-02-01',
#    'transactionCode': 'S',
#    'transactionPrice': 915.509},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 21944,
#    'change': -3156,
#    'filingDate': '2022-02-03',
#    'transactionDate': '2022-02-01',
#    'transactionCode': 'S',
#    'transactionPrice': 914.489},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 25100,
#    'change': -800,
#    'filingDate': '2022-02-03',
#    'transactionDate': '2022-02-01',
#    'transactionCode': 'S',
#    'transactionPrice': 913.403},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 25900,
#    'change': -1901,
#    'filingDate': '2022-02-03',
#    'transactionDate': '2022-02-01',
#    'transactionCode': 'S',
#    'transactionPrice': 912.278},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 27801,
#    'change': -699,
#    'filingDate': '2022-02-03',
#    'transactionDate': '2022-02-01',
#    'transactionCode': 'S',
#    'transactionPrice': 911.26},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 28500,
#    'change': -700,
#    'filingDate': '2022-02-03',
#    'transactionDate': '2022-02-01',
#    'transactionCode': 'S',
#    'transactionPrice': 908.809},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 29200,
#    'change': -400,
#    'filingDate': '2022-02-03',
#    'transactionDate': '2022-02-01',
#    'transactionCode': 'S',
#    'transactionPrice': 907.58},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 29600,
#    'change': -400,
#    'filingDate': '2022-02-03',
#    'transactionDate': '2022-02-01',
#    'transactionCode': 'S',
#    'transactionPrice': 906.293},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 30000,
#    'change': 25000,
#    'filingDate': '2022-02-03',
#    'transactionDate': '2022-02-01',
#    'transactionCode': 'M',
#    'transactionPrice': 52.38},
#   {'symbol': 'TSLA',
#    'name': 'Baglino Andrew D',
#    'share': 19249,
#    'change': -3500,
#    'filingDate': '2022-01-31',
#    'transactionDate': '2022-01-27',
#    'transactionCode': 'S',
#    'transactionPrice': 933.56},
#   {'symbol': 'TSLA',
#    'name': 'Baglino Andrew D',
#    'share': 22749,
#    'change': 3500,
#    'filingDate': '2022-01-31',
#    'transactionDate': '2022-01-27',
#    'transactionCode': 'M',
#    'transactionPrice': 62.72},
#   {'symbol': 'TSLA',
#    'name': 'Kirkhorn Zachary',
#    'share': 57334,
#    'change': -1250,
#    'filingDate': '2022-01-20',
#    'transactionDate': '2022-01-18',
#    'transactionCode': 'S',
#    'transactionPrice': 1026.75},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 24004,
#    'change': -200,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1154.675},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 24204,
#    'change': -100,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1153.31},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 24304,
#    'change': -400,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1152.485},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 24704,
#    'change': -300,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1150.977},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 25004,
#    'change': -100,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1149.45},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 25104,
#    'change': -300,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1148.05},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 25404,
#    'change': -340,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1146.924},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 25744,
#    'change': -100,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1145.21},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 25844,
#    'change': -300,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1143.403},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 26144,
#    'change': -200,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1142.455},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 26344,
#    'change': -200,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1141.145},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 26544,
#    'change': -300,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1139.67},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 26844,
#    'change': -400,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1138.738},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 27244,
#    'change': -300,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1137.173},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 27544,
#    'change': -500,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1135.762},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 28044,
#    'change': -100,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1134.24},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 28144,
#    'change': -100,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1127.43},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 28244,
#    'change': -200,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1125.095},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 28444,
#    'change': -100,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1119.75},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 28544,
#    'change': -200,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1109.835},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 28744,
#    'change': -100,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1101.52},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 28844,
#    'change': -100,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1096.9},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 28944,
#    'change': -200,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1096.195},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 29144,
#    'change': -100,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1093.95},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 29244,
#    'change': -100,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1091.86},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 29344,
#    'change': -100,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1089.68},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 29444,
#    'change': -260,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1088.348},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 29704,
#    'change': -100,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1086.72},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 29804,
#    'change': -100,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1084.65},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 29904,
#    'change': 7000,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'M',
#    'transactionPrice': 54.66},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 22904,
#    'change': -100,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1168.5},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 23004,
#    'change': -200,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1166.385},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 23204,
#    'change': -100,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1164.99},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 23304,
#    'change': -100,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1161.56},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 23404,
#    'change': -100,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1159.15},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 23504,
#    'change': -100,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1158},
#   {'symbol': 'TSLA',
#    'name': 'Taneja Vaibhav',
#    'share': 23604,
#    'change': -400,
#    'filingDate': '2022-01-07',
#    'transactionDate': '2022-01-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1156.108},
#   {'symbol': 'TSLA',
#    'name': 'Kirkhorn Zachary',
#    'share': 58584,
#    'change': 3200,
#    'filingDate': '2022-01-04',
#    'transactionDate': '2021-12-31',
#    'transactionCode': 'M',
#    'transactionPrice': 55.32},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 620086,
#    'change': -700,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1117.92},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 620786,
#    'change': -900,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1116.15},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 621686,
#    'change': -3947,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1115.081},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 625633,
#    'change': -2600,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1112.135},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 628233,
#    'change': -2008,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1110.95},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 630241,
#    'change': -500,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1109.31},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 630741,
#    'change': -15991,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1108.59},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 646732,
#    'change': -6039,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1107.516},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 652771,
#    'change': -6300,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1106.651},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 659071,
#    'change': -3475,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1105.309},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 662546,
#    'change': -6400,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1104.235},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 668946,
#    'change': -8361,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1103.087},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 677307,
#    'change': -7451,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1101.927},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 684758,
#    'change': -17100,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1101.079},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 701858,
#    'change': -27899,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1099.909},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 729757,
#    'change': -19992,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1098.908},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 749749,
#    'change': -37734,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1098.038},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 787483,
#    'change': -22324,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1096.966},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 809807,
#    'change': -26698,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1095.997},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 836505,
#    'change': -35064,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1094.999},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 871569,
#    'change': -58021,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1093.951},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 929590,
#    'change': -50243,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1093.018},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 979833,
#    'change': -64640,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1092.058},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1044473,
#    'change': -52050,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1091.01},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1096523,
#    'change': -68989,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1089.957},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1165512,
#    'change': -57541,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1088.901},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1223053,
#    'change': -74448,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1087.981},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1297501,
#    'change': -66402,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1086.963},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1363903,
#    'change': -48622,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1085.947},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1412525,
#    'change': -52594,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1084.94},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1465119,
#    'change': -49363,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1083.963},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1514482,
#    'change': -21083,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1083.043},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1535565,
#    'change': -9211,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1081.857},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1544776,
#    'change': -7000,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1080.779},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1551776,
#    'change': -2400,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'S',
#    'transactionPrice': 1079.593},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1554176,
#    'change': 1554176,
#    'filingDate': '2021-12-28',
#    'transactionDate': '2021-12-28',
#    'transactionCode': 'M',
#    'transactionPrice': 6.24},
#   {'symbol': 'TSLA',
#    'name': 'Baglino Andrew D',
#    'share': 19249,
#    'change': -3500,
#    'filingDate': '2021-12-29',
#    'transactionDate': '2021-12-27',
#    'transactionCode': 'S',
#    'transactionPrice': 1073},
#   {'symbol': 'TSLA',
#    'name': 'Baglino Andrew D',
#    'share': 22749,
#    'change': 3500,
#    'filingDate': '2021-12-29',
#    'transactionDate': '2021-12-27',
#    'transactionCode': 'M',
#    'transactionPrice': 62.72},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2325944,
#    'change': -877,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 1014.939},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2326821,
#    'change': -700,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 1013.997},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2327521,
#    'change': -2300,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 1012.584},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2329821,
#    'change': -5300,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 1011.629},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2335121,
#    'change': -18710,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 1010.809},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2353831,
#    'change': -18058,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 1009.786},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2371889,
#    'change': -37729,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 1008.804},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2409618,
#    'change': -23122,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 1007.689},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2432740,
#    'change': -44648,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 1006.795},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2477388,
#    'change': -49439,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 1005.747},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2526827,
#    'change': -48446,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 1004.776},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2575273,
#    'change': -55350,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 1003.736},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2630623,
#    'change': -32153,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 1002.697},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2662776,
#    'change': -12498,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 1001.64},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2675274,
#    'change': -27870,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 1000.669},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2703144,
#    'change': -29700,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 999.625},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2732844,
#    'change': -29480,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 998.791},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2762324,
#    'change': -30599,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 997.605},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2792923,
#    'change': -28524,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 996.545},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2821447,
#    'change': -39967,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 995.601},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2861414,
#    'change': -22088,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 994.713},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2883502,
#    'change': -18767,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 993.643},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2902269,
#    'change': -17202,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 992.688},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2919471,
#    'change': -8060,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 991.647},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2927531,
#    'change': -6926,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 990.643},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2934457,
#    'change': -22289,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 989.611},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2956746,
#    'change': -4522,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 988.823},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2961268,
#    'change': -1712,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 987.634},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2962980,
#    'change': -8379,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 986.5},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2971359,
#    'change': -8000,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 985.762},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2979359,
#    'change': -15808,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 984.513},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2995167,
#    'change': -37527,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 983.57},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 3032694,
#    'change': -34838,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 982.543},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 3067532,
#    'change': -20108,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 981.76},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 3087640,
#    'change': -22373,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 980.71},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 3110013,
#    'change': -11705,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 979.38},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 3121718,
#    'change': -25666,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 978.379},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 3147384,
#    'change': -22462,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 977.497},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 3169846,
#    'change': -17239,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 976.45},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 3187085,
#    'change': -2568,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 975.028},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 3189653,
#    'change': -15183,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 974.219},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 3204836,
#    'change': -6735,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 973.175},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 3211571,
#    'change': -8599,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 972.078},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 3220170,
#    'change': -7499,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 970.671},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 3227669,
#    'change': -3542,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 969.891},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 3231211,
#    'change': -3500,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 968.198},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 3234711,
#    'change': -1300,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 966.8},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 3236011,
#    'change': -5700,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 965.619},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 3241711,
#    'change': -4400,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 963.391},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 3246111,
#    'change': -3200,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 961.31},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 3249311,
#    'change': -4324,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 960.113},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 3253635,
#    'change': -6400,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'S',
#    'transactionPrice': 958.092},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 3260035,
#    'change': 2105171,
#    'filingDate': '2021-12-22',
#    'transactionDate': '2021-12-22',
#    'transactionCode': 'M',
#    'transactionPrice': 6.24},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1154864,
#    'change': -19,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 939.04},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1154883,
#    'change': -6617,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 937.422},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1161500,
#    'change': -5974,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 936.222},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1167474,
#    'change': -18230,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 935.23},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1185704,
#    'change': -34617,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 934.466},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1220321,
#    'change': -32667,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 933.375},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1252988,
#    'change': -46513,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 932.311},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1299501,
#    'change': -45211,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 931.455},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1344712,
#    'change': -34060,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 930.308},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1378772,
#    'change': -23470,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 929.297},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1402242,
#    'change': -21302,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 928.487},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1423544,
#    'change': -10120,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 927.468},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1433664,
#    'change': -700,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 925.866},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1434364,
#    'change': -1358,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 924.118},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1435722,
#    'change': -2300,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 923.204},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1438022,
#    'change': -1900,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 921.249},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1439922,
#    'change': -11921,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 920.672},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1451843,
#    'change': -12637,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 919.456},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1464480,
#    'change': -20162,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 918.568},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1484642,
#    'change': -20702,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 917.403},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1505344,
#    'change': -18384,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 916.519},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1523728,
#    'change': -33364,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 915.39},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1557092,
#    'change': -27587,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 914.404},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1584679,
#    'change': -16605,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 913.323},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1601284,
#    'change': -12413,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 912.371},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1613697,
#    'change': -31816,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 911.262},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1645513,
#    'change': -10207,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 910.132},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1655720,
#    'change': -33686,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 909.158},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1689406,
#    'change': -36980,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 908.312},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1726386,
#    'change': -28220,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 907.167},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1754606,
#    'change': -51795,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 906.163},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1806401,
#    'change': -39829,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 905.311},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1846230,
#    'change': -25892,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 904.195},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1872122,
#    'change': -9288,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 903.207},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1881410,
#    'change': -17867,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 902.01},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1899277,
#    'change': -5010,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 900.894},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1904287,
#    'change': -12728,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 899.925},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1917015,
#    'change': -25788,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 898.861},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1942803,
#    'change': -20375,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 898.026},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1963178,
#    'change': -21159,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 896.683},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1984337,
#    'change': -29398,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 895.785},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2013735,
#    'change': -24576,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 894.789},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2038311,
#    'change': -16465,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 893.659},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2054776,
#    'change': -10400,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 892.81},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2065176,
#    'change': -6753,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 891.921},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2071929,
#    'change': -5778,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 890.495},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2077707,
#    'change': -5948,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 889.422},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2083655,
#    'change': -1900,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 888.313},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2085555,
#    'change': -3400,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'S',
#    'transactionPrice': 886.69},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2088955,
#    'change': 2088955,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-21',
#    'transactionCode': 'M',
#    'transactionPrice': 6.24},
#   {'symbol': 'TSLA',
#    'name': 'Kirkhorn Zachary',
#    'share': 55384,
#    'change': -1250,
#    'filingDate': '2021-12-21',
#    'transactionDate': '2021-12-17',
#    'transactionCode': 'S',
#    'transactionPrice': 915},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1217849,
#    'change': -10840,
#    'filingDate': '2021-12-16',
#    'transactionDate': '2021-12-16',
#    'transactionCode': 'S',
#    'transactionPrice': 994.498},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1228689,
#    'change': -7740,
#    'filingDate': '2021-12-16',
#    'transactionDate': '2021-12-16',
#    'transactionCode': 'S',
#    'transactionPrice': 991.049},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1236429,
#    'change': -4800,
#    'filingDate': '2021-12-16',
#    'transactionDate': '2021-12-16',
#    'transactionCode': 'S',
#    'transactionPrice': 989.601},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1241229,
#    'change': -6900,
#    'filingDate': '2021-12-16',
#    'transactionDate': '2021-12-16',
#    'transactionCode': 'S',
#    'transactionPrice': 988.759},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1248129,
#    'change': -2170,
#    'filingDate': '2021-12-16',
#    'transactionDate': '2021-12-16',
#    'transactionCode': 'S',
#    'transactionPrice': 987.962},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1250299,
#    'change': -8927,
#    'filingDate': '2021-12-16',
#    'transactionDate': '2021-12-16',
#    'transactionCode': 'S',
#    'transactionPrice': 986.458},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1259226,
#    'change': -9537,
#    'filingDate': '2021-12-16',
#    'transactionDate': '2021-12-16',
#    'transactionCode': 'S',
#    'transactionPrice': 985.467},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1268763,
#    'change': -5041,
#    'filingDate': '2021-12-16',
#    'transactionDate': '2021-12-16',
#    'transactionCode': 'S',
#    'transactionPrice': 982.298},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1273804,
#    'change': -4957,
#    'filingDate': '2021-12-16',
#    'transactionDate': '2021-12-16',
#    'transactionCode': 'S',
#    'transactionPrice': 980.797},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1278761,
#    'change': -9400,
#    'filingDate': '2021-12-16',
#    'transactionDate': '2021-12-16',
#    'transactionCode': 'S',
#    'transactionPrice': 979.719},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1288161,
#    'change': -8751,
#    'filingDate': '2021-12-16',
#    'transactionDate': '2021-12-16',
#    'transactionCode': 'S',
#    'transactionPrice': 978.597},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1296912,
#    'change': -4491,
#    'filingDate': '2021-12-16',
#    'transactionDate': '2021-12-16',
#    'transactionCode': 'S',
#    'transactionPrice': 977.358},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1301403,
#    'change': -6450,
#    'filingDate': '2021-12-16',
#    'transactionDate': '2021-12-16',
#    'transactionCode': 'S',
#    'transactionPrice': 976.443},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1307853,
#    'change': -16276,
#    'filingDate': '2021-12-16',
#    'transactionDate': '2021-12-16',
#    'transactionCode': 'S',
#    'transactionPrice': 975.19},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1324129,
#    'change': -3015,
#    'filingDate': '2021-12-16',
#    'transactionDate': '2021-12-16',
#    'transactionCode': 'S',
#    'transactionPrice': 973.521},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1327144,
#    'change': -3979,
#    'filingDate': '2021-12-16',
#    'transactionDate': '2021-12-16',
#    'transactionCode': 'S',
#    'transactionPrice': 972.718},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1331123,
#    'change': -9373,
#    'filingDate': '2021-12-16',
#    'transactionDate': '2021-12-16',
#    'transactionCode': 'S',
#    'transactionPrice': 971.741},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1340496,
#    'change': -400,
#    'filingDate': '2021-12-16',
#    'transactionDate': '2021-12-16',
#    'transactionCode': 'S',
#    'transactionPrice': 969.91},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1340896,
#    'change': -6201,
#    'filingDate': '2021-12-16',
#    'transactionDate': '2021-12-16',
#    'transactionCode': 'S',
#    'transactionPrice': 969.044},
#   {'symbol': 'TSLA',
# ...
#    'transactionPrice': 1185.791},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1599196,
#    'change': -72241,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1184.681},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1671437,
#    'change': -78191,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1183.754},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1749628,
#    'change': -42615,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1182.718},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1792243,
#    'change': -43643,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1181.636},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1835886,
#    'change': -33171,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1180.811},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1869057,
#    'change': -10685,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1179.744},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1879742,
#    'change': -2300,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1178.392},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1882042,
#    'change': -7049,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1177.721},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1889091,
#    'change': -8202,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1176.585},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1897293,
#    'change': -6020,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1175.654},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1903313,
#    'change': -5559,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1174.611},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1908872,
#    'change': -10002,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1173.558},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1918874,
#    'change': -11540,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1172.526},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1930414,
#    'change': -13786,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1171.637},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1944200,
#    'change': -19600,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1170.486},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1963800,
#    'change': -22061,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1169.154},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 1985861,
#    'change': -19428,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1167.997},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2005289,
#    'change': -25710,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1166.983},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2030999,
#    'change': -21383,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1165.92},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2052382,
#    'change': -18753,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1164.836},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2071135,
#    'change': -24718,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1163.655},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2095853,
#    'change': -5100,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1162.867},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2100953,
#    'change': -10316,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1161.54},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2111269,
#    'change': -7254,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1160.638},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2118523,
#    'change': -6100,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1158.192},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2124623,
#    'change': -600,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1156.55},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2125223,
#    'change': -1700,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1155.276},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2126923,
#    'change': -2049,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1153.38},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2128972,
#    'change': -800,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1152.05},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2129772,
#    'change': -7500,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1149.327},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2137272,
#    'change': -1900,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1147.995},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2139172,
#    'change': -3300,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1146.123},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2142472,
#    'change': -1300,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1143.559},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2143772,
#    'change': -400,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1142.05},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2144172,
#    'change': -6400,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1141.05},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2150572,
#    'change': -2300,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1139.487},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2152872,
#    'change': -600,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1138},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2153472,
#    'change': -1100,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'S',
#    'transactionPrice': 1135.05},
#   {'symbol': 'TSLA',
#    'name': 'Musk Elon',
#    'share': 2154572,
#    'change': 2154572,
#    'filingDate': '2021-11-10',
#    'transactionDate': '2021-11-08',
#    'transactionCode': 'M',
#    'transactionPrice': 6.24},
#   {'symbol': 'TSLA',
#    'name': 'Musk Kimbal',
#    'share': 511240,
#    'change': -500,
#    'filingDate': '2021-11-05',
#    'transactionDate': '2021-11-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1236.623},
#   {'symbol': 'TSLA',
#    'name': 'Musk Kimbal',
#    'share': 511740,
#    'change': -2460,
#    'filingDate': '2021-11-05',
#    'transactionDate': '2021-11-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1235.105},
#   {'symbol': 'TSLA',
#    'name': 'Musk Kimbal',
#    'share': 514200,
#    'change': -9810,
#    'filingDate': '2021-11-05',
#    'transactionDate': '2021-11-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1234.322},
#   {'symbol': 'TSLA',
#    'name': 'Musk Kimbal',
#    'share': 524010,
#    'change': -10455,
#    'filingDate': '2021-11-05',
#    'transactionDate': '2021-11-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1233.082},
#   {'symbol': 'TSLA',
#    'name': 'Musk Kimbal',
#    'share': 534465,
#    'change': -850,
#    'filingDate': '2021-11-05',
#    'transactionDate': '2021-11-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1232.449},
#   {'symbol': 'TSLA',
#    'name': 'Musk Kimbal',
#    'share': 535315,
#    'change': -600,
#    'filingDate': '2021-11-05',
#    'transactionDate': '2021-11-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1230.939},
#   {'symbol': 'TSLA',
#    'name': 'Musk Kimbal',
#    'share': 535915,
#    'change': -14257,
#    'filingDate': '2021-11-05',
#    'transactionDate': '2021-11-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1229.677},
#   {'symbol': 'TSLA',
#    'name': 'Musk Kimbal',
#    'share': 550172,
#    'change': -9334,
#    'filingDate': '2021-11-05',
#    'transactionDate': '2021-11-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1229.146},
#   {'symbol': 'TSLA',
#    'name': 'Musk Kimbal',
#    'share': 559506,
#    'change': -1301,
#    'filingDate': '2021-11-05',
#    'transactionDate': '2021-11-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1227.352},
#   {'symbol': 'TSLA',
#    'name': 'Musk Kimbal',
#    'share': 560807,
#    'change': -21051,
#    'filingDate': '2021-11-05',
#    'transactionDate': '2021-11-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1226.553},
#   {'symbol': 'TSLA',
#    'name': 'Musk Kimbal',
#    'share': 581858,
#    'change': -11302,
#    'filingDate': '2021-11-05',
#    'transactionDate': '2021-11-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1225.789},
#   {'symbol': 'TSLA',
#    'name': 'Musk Kimbal',
#    'share': 593160,
#    'change': -1664,
#    'filingDate': '2021-11-05',
#    'transactionDate': '2021-11-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1224.959},
#   {'symbol': 'TSLA',
#    'name': 'Musk Kimbal',
#    'share': 594824,
#    'change': -4916,
#    'filingDate': '2021-11-05',
#    'transactionDate': '2021-11-05',
#    'transactionCode': 'S',
#    'transactionPrice': 1223.459},
#   {'symbol': 'TSLA',
#    'name': 'Musk Kimbal',
#    'share': 599740,
#    'change': 25000,
#    'filingDate': '2021-11-05',
#    'transactionDate': '2021-11-05',
#    'transactionCode': 'M',
#    'transactionPrice': 74.17},
#   {'symbol': 'TSLA',
#    'name': 'Musk Kimbal',
#    'share': 574740,
#    'change': -25000,
#    'filingDate': '2021-11-05',
#    'transactionDate': '2021-11-05',
#    'transactionCode': 'G',
#    'transactionPrice': 0},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 5000,
#    'change': -450,
#    'filingDate': '2021-11-03',
#    'transactionDate': '2021-11-01',
#    'transactionCode': 'S',
#    'transactionPrice': 1147.312},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 5450,
#    'change': -1292,
#    'filingDate': '2021-11-03',
#    'transactionDate': '2021-11-01',
#    'transactionCode': 'S',
#    'transactionPrice': 1146.117},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 6742,
#    'change': -14300,
#    'filingDate': '2021-11-03',
#    'transactionDate': '2021-11-01',
#    'transactionCode': 'S',
#    'transactionPrice': 1144.992},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 21042,
#    'change': -533,
#    'filingDate': '2021-11-03',
#    'transactionDate': '2021-11-01',
#    'transactionCode': 'S',
#    'transactionPrice': 1143.922},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 21575,
#    'change': -480,
#    'filingDate': '2021-11-03',
#    'transactionDate': '2021-11-01',
#    'transactionCode': 'S',
#    'transactionPrice': 1142.593},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 22055,
#    'change': -704,
#    'filingDate': '2021-11-03',
#    'transactionDate': '2021-11-01',
#    'transactionCode': 'S',
#    'transactionPrice': 1141.47},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 22759,
#    'change': -1191,
#    'filingDate': '2021-11-03',
#    'transactionDate': '2021-11-01',
#    'transactionCode': 'S',
#    'transactionPrice': 1140.083},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 23950,
#    'change': -100,
#    'filingDate': '2021-11-03',
#    'transactionDate': '2021-11-01',
#    'transactionCode': 'S',
#    'transactionPrice': 1137.94},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 24050,
#    'change': -100,
#    'filingDate': '2021-11-03',
#    'transactionDate': '2021-11-01',
#    'transactionCode': 'S',
#    'transactionPrice': 1136.86},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 24150,
#    'change': -500,
#    'filingDate': '2021-11-03',
#    'transactionDate': '2021-11-01',
#    'transactionCode': 'S',
#    'transactionPrice': 1133.665},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 24650,
#    'change': -2070,
#    'filingDate': '2021-11-03',
#    'transactionDate': '2021-11-01',
#    'transactionCode': 'S',
#    'transactionPrice': 1132.947},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 26720,
#    'change': -2147,
#    'filingDate': '2021-11-03',
#    'transactionDate': '2021-11-01',
#    'transactionCode': 'S',
#    'transactionPrice': 1132.075},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 28867,
#    'change': -1133,
#    'filingDate': '2021-11-03',
#    'transactionDate': '2021-11-01',
#    'transactionCode': 'S',
#    'transactionPrice': 1130.928},
#   {'symbol': 'TSLA',
#    'name': 'DENHOLM ROBYN M',
#    'share': 30000,
#    'change': 25000,
#    'filingDate': '2021-11-03',
#    'transactionDate': '2021-11-01',
#    'transactionCode': 'M',
#    'transactionPrice': 52.38},
#   {'symbol': 'TSLA',
#    'name': 'Baglino Andrew D',
#    'share': 18380,
#    'change': -1000,
#    'filingDate': '2021-10-29',
#    'transactionDate': '2021-10-27',
#    'transactionCode': 'S',
#    'transactionPrice': 1038.18},
#   {'symbol': 'TSLA',
#    'name': 'Baglino Andrew D',
#    'share': 19380,
#    'change': 1000,
#    'filingDate': '2021-10-29',
#    'transactionDate': '2021-10-27',
#    'transactionCode': 'M',
#    'transactionPrice': 51.64},
#   {'symbol': 'TSLA',
#    'name': 'Ehrenpreis Ira Matthew',
#    'share': 190335,
#    'change': -1300,
#    'filingDate': '2021-10-28',
#    'transactionDate': '2021-10-27',
#    'transactionCode': 'S',
#    'transactionPrice': 1068.383},
#   {'symbol': 'TSLA',
#    'name': 'Ehrenpreis Ira Matthew',
#    'share': 191635,
#    'change': -1148,
#    'filingDate': '2021-10-28',
#    'transactionDate': '2021-10-27',
#    'transactionCode': 'S',
#    'transactionPrice': 1066.902},
#   {'symbol': 'TSLA',
#    'name': 'Ehrenpreis Ira Matthew',
#    'share': 192783,
#    'change': -5800,
#    'filingDate': '2021-10-28',
#    'transactionDate': '2021-10-27',
#    'transactionCode': 'S',
#    'transactionPrice': 1064.351},
#   {'symbol': 'TSLA',
#    'name': 'Ehrenpreis Ira Matthew',
#    'share': 198583,
#    'change': -7151,
#    'filingDate': '2021-10-28',
#    'transactionDate': '2021-10-27',
#    'transactionCode': 'S',
#    'transactionPrice': 1063.17},
#   ...],
#  'symbol': 'TSLA'}

# %%
# Convert the data into a dataframe.
df = pd.DataFrame(data=test['data'])

# Derived attributes from the data.
df['dollarAmount'] = df['change']*df['transactionPrice']
df['insiderPortfolioChange'] = df['change']/(df['share'] - df['change'])

# print(type(df['transactionPrice'][0]))
conditions = [
    (df['change'] >= 0) & (df['transactionPrice'] > 0),
    (df['change'] <= 0) & (df['transactionPrice'] > 0),
    (df['transactionPrice'] == 0)
]
values = ['Buy', 'Sale', 'Gift']
df['buyOrSale'] = np.select(conditions, values)

print(df)

# df.to_csv('YOUR PATH\\'+stock+'.csv', index=False)
# Out:
#      symbol              name  share  change  filingDate transactionDate  \
# 0      TSLA   DENHOLM ROBYN M   5000  -10100  2022-02-03      2022-02-01
# 1      TSLA   DENHOLM ROBYN M  15100    -300  2022-02-03      2022-02-01
# 2      TSLA   DENHOLM ROBYN M  15400    -200  2022-02-03      2022-02-01
# 3      TSLA   DENHOLM ROBYN M  15600    -100  2022-02-03      2022-02-01
# 4      TSLA   DENHOLM ROBYN M  15700    -600  2022-02-03      2022-02-01
# ...     ...               ...    ...     ...         ...             ...
# 1277   TSLA    Taneja Vaibhav  19001     385  2021-03-09      2021-03-05
# 1278   TSLA    Taneja Vaibhav  18616    2250  2021-03-09      2021-03-05
# 1279   TSLA  Guillen Jerome M  51207    1211  2021-03-09      2021-03-05
# 1280   TSLA  Baglino Andrew D  18726   -1500  2021-03-03      2021-03-01
# 1281   TSLA  Baglino Andrew D  20226    1000  2021-03-03      2021-03-01
#
#      transactionCode  transactionPrice  dollarAmount  insiderPortfolioChange  \
# 0                  S           934.124    -9434652.4               -0.668874
# 1                  S           932.853     -279855.9               -0.019481
# 2                  S           931.655     -186331.0               -0.012821
# 3                  S           929.890      -92989.0               -0.006369
# 4                  S           926.482     -555889.2               -0.036810
# ...              ...               ...           ...                     ...
# 1277               M             0.000           0.0                0.020681
# 1278               M             0.000           0.0                0.137480
# 1279               M             0.000           0.0                0.024222
# 1280               S           690.110    -1035165.0               -0.074162
# 1281               M            41.570       41570.0                0.052013
#
#      buyOrSale
# 0         Sale
# 1         Sale
# 2         Sale
# 3         Sale
# 4         Sale
# ...        ...
# 1277      Gift
# 1278      Gift
# 1279      Gift
# 1280      Sale
# 1281       Buy
#
# [1282 rows x 11 columns]
